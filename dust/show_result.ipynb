# %%
import json
import ast
from datetime import datetime as dt
import datetime

import pandas as pd
import plotly.express as px

# %%
rst = []
with open("file.txt",'r') as f:
    rst = f.read()

# %%
rsts = rst.split(",\n")

# %%
dicts = []
err_cnt = 0
for _rst in rsts :
    try:
        _dict = ast.literal_eval(_rst)
#         _dict['write_time'] = dt.strptime(_dict['write_time'][:-2],"%Y%m%d%H%M%S%f")
        _dict['write_time'] = dt.fromtimestamp(int(_dict['write_time'][12:]))
        dicts.append(_dict)
    except Exception as e:
#         print(e)
        err_cnt+=1
print(err_cnt)
# Out:
# 1

# %% [markdown]
# ### Raw

# %%
df= pd.DataFrame(dicts)
df  = df.reset_index()

# %%
df.loc[:,'concentration_ma'] = df.loc[:,'concentration'].rolling(10).mean()/1000

# %%
fig = px.line(df, x='write_time', y="concentration_ma")
fig.show()
# Out:
# <div>                            <div id="bcc6c7f2-36e1-4bc2-b910-cefd4c3e7f91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcc6c7f2-36e1-4bc2-b910-cefd4c3e7f91")) {                    Plotly.newPlot(                        "bcc6c7f2-36e1-4bc2-b910-cefd4c3e7f91",                        [{"hovertemplate":"write_time=%{x}<br>concentration_ma=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"type":"scattergl","x":["2021-09-08T17:11:00","2021-09-08T17:11:30","2021-09-08T17:12:00","2021-09-08T17:12:30","2021-09-08T17:13:00","2021-09-08T17:13:30","2021-09-08T17:14:00","2021-09-08T17:14:30","2021-09-08T17:15:00","2021-09-08T17:15:30","2021-09-08T17:16:00","2021-09-08T17:16:30","2021-09-08T17:17:00","2021-09-08T17:17:30","2021-09-08T17:18:00","2021-09-08T17:18:30","2021-09-08T17:19:00","2021-09-08T17:19:30","2021-09-08T17:20:00","2021-09-08T17:20:30","2021-09-08T17:21:00","2021-09-08T17:21:30","2021-09-08T17:22:00","2021-09-08T17:22:30","2021-09-08T17:23:00","2021-09-08T17:23:30","2021-09-08T17:24:00","2021-09-08T17:24:30","2021-09-08T17:25:00","2021-09-08T17:25:30","2021-09-08T17:26:00","2021-09-08T17:26:30","2021-09-08T17:27:00","2021-09-08T17:27:30","2021-09-08T17:28:00","2021-09-08T17:28:30","2021-09-08T17:29:00","2021-09-08T17:29:30","2021-09-08T17:30:00","2021-09-08T17:30:30","2021-09-08T17:31:00","2021-09-08T17:31:30","2021-09-08T17:32:00","2021-09-08T17:32:30","2021-09-08T17:33:00","2021-09-08T17:33:30","2021-09-08T17:34:00","2021-09-08T17:34:30","2021-09-08T17:35:00","2021-09-08T17:35:30","2021-09-08T17:36:00","2021-09-08T17:36:30","2021-09-08T17:37:00","2021-09-08T17:37:30","2021-09-08T17:38:00","2021-09-08T17:38:30","2021-09-08T17:39:00","2021